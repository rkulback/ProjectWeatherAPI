# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

import openweathermapy.core as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities_list = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities_list:
        cities_list.append(city)

# Print the city count to confirm sufficient count

#citied_df = pd.DataFrame(cities)

#citied_df.head()

# %%
# Save config information.
weather_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
weather_url = f"{weather_url}appid={api_key}&units={units}&q="

# set up lists to hold reponse info
humidity = []
temp = []
test_lat = []
test_lng = []
windspeed = []
cloudiness = []

# Loop through the list of cities and perform a request for data on each
for city in cities_list:
    weather_info = requests.get(weather_url + city).json()
    
    try:
        test_lat.append(weather_info['coord']['lat'])
    
    except KeyError as exception:
        
        print(f"no latitude data for {city} available")
        
    try:
        test_lng.append(weather_info['coord']['lon'])
    
    except KeyError as exception:
        
        print(f"no longitude data for {city} available")
        
    try:
        temp.append(weather_info['main']['temp'])
    
    except KeyError as exception:
        
        print(f"no temperature data for {city} available")
        
    try:
        humidity.append(weather_info['main']['humidity'])
    
    except KeyError as exception:
        
        print(f"no humidity data for {city} available")
        
    try:
        windspeed.append(weather_info['wind']['speed'])
        
    except KeyError as exception:
        
        print(f"no windspeed data for {city} available")
        
    try:
        cloudiness.append(weather_info['clouds']['all'])
        
    except KeyError as exception:
        
        print(f"no cloudiness data for {city} available")
        
    print(f"gathering temperature, coordinates, humidity, cloudiness, and windspeed information for {city}.")
# Out:
# no latitude data for taolanaro available
# no longitude data for taolanaro available
# no temperature data for taolanaro available
# no humidity data for taolanaro available
# no windspeed data for taolanaro available
# no cloudiness data for taolanaro available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for taolanaro.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mar del plata.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for barrow.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for yulara.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for richards bay.
# no latitude data for arrecife available
# no longitude data for arrecife available
# no temperature data for arrecife available
# no humidity data for arrecife available
# no windspeed data for arrecife available
# no cloudiness data for arrecife available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for arrecife.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for busselton.
# no latitude data for illoqqortoormiut available
# no longitude data for illoqqortoormiut available
# no temperature data for illoqqortoormiut available
# no humidity data for illoqqortoormiut available
# no windspeed data for illoqqortoormiut available
# no cloudiness data for illoqqortoormiut available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for illoqqortoormiut.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for yeppoon.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for punta arenas.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bluff.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for marawi.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for arraial do cabo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for lebu.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for salina cruz.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kavaratti.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nantucket.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kapaa.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for chokurdakh.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tuktoyaktuk.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for cherskiy.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for santa luzia.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mataura.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for alekseyevka.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ushuaia.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for vaini.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for maragogi.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for port alfred.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for saint george.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for rio grande.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for hermanus.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for rikitea.
# no latitude data for tsihombe available
# no longitude data for tsihombe available
# no temperature data for tsihombe available
# no humidity data for tsihombe available
# no windspeed data for tsihombe available
# no cloudiness data for tsihombe available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tsihombe.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nadym.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for east london.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for hobart.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for cape town.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for new norfolk.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for khatanga.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for dingle.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for torbay.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for auki.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for atuona.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for hilo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for saint-augustin.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ahipara.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for semirom.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for port elizabeth.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for albany.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nouadhibou.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kautokeino.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ada.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for milkovo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for vila velha.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ixtapa.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for launceston.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for carnarvon.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for butaritari.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for zhenhai.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for buala.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for goderich.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kodiak.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nabire.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kalmunai.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for arman.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for abha.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sadiqabad.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for pevek.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for portland.
# no latitude data for olafsvik available
# no longitude data for olafsvik available
# no temperature data for olafsvik available
# no humidity data for olafsvik available
# no windspeed data for olafsvik available
# no cloudiness data for olafsvik available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for olafsvik.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for talnakh.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for provideniya.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for lompoc.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mount isa.
# no latitude data for mys shmidta available
# no longitude data for mys shmidta available
# no temperature data for mys shmidta available
# no humidity data for mys shmidta available
# no windspeed data for mys shmidta available
# no cloudiness data for mys shmidta available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mys shmidta.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for yumen.
# no latitude data for sentyabrskiy available
# no longitude data for sentyabrskiy available
# no temperature data for sentyabrskiy available
# no humidity data for sentyabrskiy available
# no windspeed data for sentyabrskiy available
# no cloudiness data for sentyabrskiy available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sentyabrskiy.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for gigmoto.
# no latitude data for belushya guba available
# no longitude data for belushya guba available
# no temperature data for belushya guba available
# no humidity data for belushya guba available
# no windspeed data for belushya guba available
# no cloudiness data for belushya guba available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for belushya guba.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tiksi.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for rassvet.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for riyadh.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for warsaw.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for constitucion.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ostrovnoy.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for doha.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for lufilufi.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ahualulco.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for muisne.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for victoria.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for san patricio.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for xam nua.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for faya.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bima.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for were ilu.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for merauke.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sahuaripa.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ardalstangen.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for dawei.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nhulunbuy.
# no latitude data for ye available
# no longitude data for ye available
# no temperature data for ye available
# no humidity data for ye available
# no windspeed data for ye available
# no cloudiness data for ye available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ye.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ilhabela.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for dinuba.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kusu.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bocanegra.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for puro.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ribeira grande.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for fairbanks.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for vestmannaeyjar.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for muhos.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for chuy.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for fortuna.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nikolskoye.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for narsaq.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for port hedland.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for teguise.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for upernavik.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for havre-saint-pierre.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for grand gaube.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for hithadhoo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for conceicao da barra.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for miles city.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tshikapa.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sitka.
# no latitude data for vitimskiy available
# no longitude data for vitimskiy available
# no temperature data for vitimskiy available
# no humidity data for vitimskiy available
# no windspeed data for vitimskiy available
# no cloudiness data for vitimskiy available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for vitimskiy.
# no latitude data for odweyne available
# no longitude data for odweyne available
# no temperature data for odweyne available
# no humidity data for odweyne available
# no windspeed data for odweyne available
# no cloudiness data for odweyne available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for odweyne.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ponta do sol.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mata.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for jacareacanga.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for emba.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sambava.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for wanning.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for san ignacio.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ionia.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for thomaston.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for pacific grove.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for boa vista.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for oksfjord.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sladkovo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for thompson.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for villa guerrero.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for georgetown.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for callosa de segura.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kulhudhuffushi.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for matadi.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kruisfontein.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for coihaique.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for abapo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for yellowknife.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kaitangata.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for shadrinsk.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kilindoni.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for gizo.
# no latitude data for sumbawa available
# no longitude data for sumbawa available
# no temperature data for sumbawa available
# no humidity data for sumbawa available
# no windspeed data for sumbawa available
# no cloudiness data for sumbawa available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sumbawa.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for geraldton.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for le port.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for puerto ayora.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for anadyr.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bodden town.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for banda aceh.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for joao pinheiro.
# no latitude data for svetlyy available
# no longitude data for svetlyy available
# no temperature data for svetlyy available
# no humidity data for svetlyy available
# no windspeed data for svetlyy available
# no cloudiness data for svetlyy available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for svetlyy.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for wajid.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for jamestown.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for dikson.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for takoradi.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for suntar.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for eyl.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for haimen.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mocuba.
# no latitude data for maridi available
# no longitude data for maridi available
# no temperature data for maridi available
# no humidity data for maridi available
# no windspeed data for maridi available
# no cloudiness data for maridi available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for maridi.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for leh.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for siocon.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for flinders.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tasiilaq.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for husavik.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kaabong.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for san miguel.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kupang.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kavieng.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for byron bay.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sabang.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for barra do garcas.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for qaanaaq.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for fort wellington.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for innisfail.
# no latitude data for samusu available
# no longitude data for samusu available
# no temperature data for samusu available
# no humidity data for samusu available
# no windspeed data for samusu available
# no cloudiness data for samusu available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for samusu.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for marsh harbour.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ahtopol.
# no latitude data for barawe available
# no longitude data for barawe available
# no temperature data for barawe available
# no humidity data for barawe available
# no windspeed data for barawe available
# no cloudiness data for barawe available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for barawe.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for havelock.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for norman wells.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for salina.
# no latitude data for karaul available
# no longitude data for karaul available
# no temperature data for karaul available
# no humidity data for karaul available
# no windspeed data for karaul available
# no cloudiness data for karaul available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for karaul.
# no latitude data for nizhneyansk available
# no longitude data for nizhneyansk available
# no temperature data for nizhneyansk available
# no humidity data for nizhneyansk available
# no windspeed data for nizhneyansk available
# no cloudiness data for nizhneyansk available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nizhneyansk.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for trincomalee.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kushima.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for cidreira.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for zhigansk.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for praya.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for pontes e lacerda.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sechura.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for benemerito de las americas.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for caravelas.
# no latitude data for karkaralinsk available
# no longitude data for karkaralinsk available
# no temperature data for karkaralinsk available
# no humidity data for karkaralinsk available
# no windspeed data for karkaralinsk available
# no cloudiness data for karkaralinsk available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for karkaralinsk.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for whitehorse.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for russell.
# no latitude data for bo available
# no longitude data for bo available
# no temperature data for bo available
# no humidity data for bo available
# no windspeed data for bo available
# no cloudiness data for bo available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for buchen.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for namwala.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for harper.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nanortalik.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for soyaux.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for zyryanka.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for rio gallegos.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bredasdorp.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ambilobe.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for qaqortoq.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nurota.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bosaso.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tuy hoa.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for saint-philippe.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for comodoro rivadavia.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for saint-joseph.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for carauari.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for pindiga.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tessalit.
# no latitude data for warqla available
# no longitude data for warqla available
# no temperature data for warqla available
# no humidity data for warqla available
# no windspeed data for warqla available
# no cloudiness data for warqla available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for warqla.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for skibbereen.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bonavista.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for anito.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for chicama.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for airai.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for saint anthony.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for pavlogradka.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bambous virieux.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ormara.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for port macquarie.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for porto torres.
# no latitude data for barbar available
# no longitude data for barbar available
# no temperature data for barbar available
# no humidity data for barbar available
# no windspeed data for barbar available
# no cloudiness data for barbar available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for barbar.
# no latitude data for tambura available
# no longitude data for tambura available
# no temperature data for tambura available
# no humidity data for tambura available
# no windspeed data for tambura available
# no cloudiness data for tambura available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tambura.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tura.
# no latitude data for lago da pedra available
# no longitude data for lago da pedra available
# no temperature data for lago da pedra available
# no humidity data for lago da pedra available
# no windspeed data for lago da pedra available
# no cloudiness data for lago da pedra available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for lago da pedra.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for pedernales.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for coquimbo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bitung.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for jimeta.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tangzhai.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tuatapere.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for maceio.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for carutapera.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for saskylakh.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for voyvozh.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tromso.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for magna.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for college.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ridgecrest.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for walvis bay.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mahon.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for omboue.
# no latitude data for barentsburg available
# no longitude data for barentsburg available
# no temperature data for barentsburg available
# no humidity data for barentsburg available
# no windspeed data for barentsburg available
# no cloudiness data for barentsburg available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for barentsburg.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for faanui.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mecca.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for saint-maximin-la-sainte-baume.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for deder.
# no latitude data for acarau available
# no longitude data for acarau available
# no temperature data for acarau available
# no humidity data for acarau available
# no windspeed data for acarau available
# no cloudiness data for acarau available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for acarau.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for los llanos de aridane.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tarko-sale.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mishelevka.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for lusaka.
# no latitude data for amderma available
# no longitude data for amderma available
# no temperature data for amderma available
# no humidity data for amderma available
# no windspeed data for amderma available
# no cloudiness data for amderma available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for amderma.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for belyy yar.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for isangel.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sistranda.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for emet.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for brae.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for leningradskiy.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for vardo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for paamiut.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for lagoa.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mayumba.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for izmit.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for shatrovo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sapele.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for high level.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bela.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for marathon.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ust-tsilma.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bonito.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for viedma.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mokhsogollokh.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for neiafu.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for camacha.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for cape coast.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for plouzane.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for san cristobal.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mohan.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for vila franca do campo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mount gambier.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for codrington.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for belaya gora.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for povenets.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for beloha.
# no latitude data for grand river south east available
# no longitude data for grand river south east available
# no temperature data for grand river south east available
# no humidity data for grand river south east available
# no windspeed data for grand river south east available
# no cloudiness data for grand river south east available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for grand river south east.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for astorga.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for aguilas.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for changzhou.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for rawson.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bantogon.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mayo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for hambantota.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for suaita.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for poirino.
# no latitude data for rungata available
# no longitude data for rungata available
# no temperature data for rungata available
# no humidity data for rungata available
# no windspeed data for rungata available
# no cloudiness data for rungata available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for rungata.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ondangwa.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for beringovskiy.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for longyearbyen.
# no latitude data for lolua available
# no longitude data for lolua available
# no temperature data for lolua available
# no humidity data for lolua available
# no windspeed data for lolua available
# no cloudiness data for lolua available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for lolua.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for santa maria.
# no latitude data for mananara available
# no longitude data for mananara available
# no temperature data for mananara available
# no humidity data for mananara available
# no windspeed data for mananara available
# no cloudiness data for mananara available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mananara.
# no latitude data for fevralsk available
# no longitude data for fevralsk available
# no temperature data for fevralsk available
# no humidity data for fevralsk available
# no windspeed data for fevralsk available
# no cloudiness data for fevralsk available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for fevralsk.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ternate.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for port hardy.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for taksimo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nanakuli.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for khasan.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for longhua.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for winnemucca.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for safranbolu.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for dunedin.
# no latitude data for karmana available
# no longitude data for karmana available
# no temperature data for karmana available
# no humidity data for karmana available
# no windspeed data for karmana available
# no cloudiness data for karmana available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for karmana.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for islamkot.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nyurba.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for saint johnsbury.
# no latitude data for tasbuget available
# no longitude data for tasbuget available
# no temperature data for tasbuget available
# no humidity data for tasbuget available
# no windspeed data for tasbuget available
# no cloudiness data for tasbuget available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tasbuget.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kirakira.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for castro.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for meulaboh.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for obihiro.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for guacimo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for pangoa.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for shumskiy.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for cooma.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for homer.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for key largo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kuala terengganu.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for norsup.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for yarada.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for santa clara.
# no latitude data for safaga available
# no longitude data for safaga available
# no temperature data for safaga available
# no humidity data for safaga available
# no windspeed data for safaga available
# no cloudiness data for safaga available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for safaga.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for gorkovskiy.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for at-bashi.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for elizabeth city.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for omsukchan.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for cayenne.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for cururupu.
# no latitude data for vaitupu available
# no longitude data for vaitupu available
# no temperature data for vaitupu available
# no humidity data for vaitupu available
# no windspeed data for vaitupu available
# no cloudiness data for vaitupu available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for vaitupu.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for port-gentil.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for taoudenni.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mahebourg.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ancud.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for manica.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for hendaye.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for srednekolymsk.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for iqaluit.
# no latitude data for yunjinghong available
# no longitude data for yunjinghong available
# no temperature data for yunjinghong available
# no humidity data for yunjinghong available
# no windspeed data for yunjinghong available
# no cloudiness data for yunjinghong available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for yunjinghong.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sinnamary.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sivas.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for susanville.
# no latitude data for kuche available
# no longitude data for kuche available
# no temperature data for kuche available
# no humidity data for kuche available
# no windspeed data for kuche available
# no cloudiness data for kuche available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kuche.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for grindavik.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for guerrero negro.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bethel.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for hasaki.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bowen.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for maravilha.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for saint-georges.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kendari.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for verkh-usugli.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for immokalee.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for digby.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for solnechnyy.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for salalah.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for pandan.
# no latitude data for zachagansk available
# no longitude data for zachagansk available
# no temperature data for zachagansk available
# no humidity data for zachagansk available
# no windspeed data for zachagansk available
# no cloudiness data for zachagansk available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for zachagansk.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mwinilunga.
# no latitude data for burica available
# no longitude data for burica available
# no temperature data for burica available
# no humidity data for burica available
# no windspeed data for burica available
# no cloudiness data for burica available
# ...
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for severo-kurilsk.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for isla mujeres.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nuuk.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for conceicao do araguaia.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for namatanai.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for pisco.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for laguna.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for udayagiri.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for keita.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ordynskoye.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for leshukonskoye.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for huarmey.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for taltal.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for cabedelo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kiruna.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mandalay.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mosquera.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for myre.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for maine-soroa.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for yokadouma.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ponta delgada.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for hit.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for jumla.
# no latitude data for kamenskoye available
# no longitude data for kamenskoye available
# no temperature data for kamenskoye available
# no humidity data for kamenskoye available
# no windspeed data for kamenskoye available
# no cloudiness data for kamenskoye available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kamenskoye.
# no latitude data for mahonda available
# no longitude data for mahonda available
# no temperature data for mahonda available
# no humidity data for mahonda available
# no windspeed data for mahonda available
# no cloudiness data for mahonda available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mahonda.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for chengde.
# no latitude data for maqrin available
# no longitude data for maqrin available
# no temperature data for maqrin available
# no humidity data for maqrin available
# no windspeed data for maqrin available
# no cloudiness data for maqrin available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for maqrin.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for cobija.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for carupano.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sterling.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for leon.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nelson bay.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for berlevag.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for fort nelson.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for itarema.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for key west.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for loandjili.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ushibuka.
# no latitude data for chagda available
# no longitude data for chagda available
# no temperature data for chagda available
# no humidity data for chagda available
# no windspeed data for chagda available
# no cloudiness data for chagda available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for chagda.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for zaria.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ausa.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for lensk.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for herouville-saint-clair.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for alihe.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for rio verde de mato grosso.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for yichang.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for port lincoln.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for morgan city.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bougouni.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for sayyan.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ciudad bolivar.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for boli.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for dergachi.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for baykit.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for agbor.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for daru.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for hokitika.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for komsomolskiy.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for huangpi.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for san gabriel.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for charters towers.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for yagodnoye.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for esperance.
# no latitude data for gurupa available
# no longitude data for gurupa available
# no temperature data for gurupa available
# no humidity data for gurupa available
# no windspeed data for gurupa available
# no cloudiness data for gurupa available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for gurupa.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kutum.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for rock sound.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for dori.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bacolod.
# no latitude data for palabuhanratu available
# no longitude data for palabuhanratu available
# no temperature data for palabuhanratu available
# no humidity data for palabuhanratu available
# no windspeed data for palabuhanratu available
# no cloudiness data for palabuhanratu available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for palabuhanratu.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for peace river.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nianzishan.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for dordrecht.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for broken hill.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mahajanga.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for namibe.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for pori.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for yaypan.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for helena.
# no latitude data for kleck available
# no longitude data for kleck available
# no temperature data for kleck available
# no humidity data for kleck available
# no windspeed data for kleck available
# no cloudiness data for kleck available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kleck.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tautira.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for chamrajnagar.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for zabaykalsk.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for asbury park.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for talara.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for shingu.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for rock springs.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for itoman.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for nowy dwor gdanski.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for tomatlan.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for krabi.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for moyobamba.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for pochutla.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for alyangula.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kahului.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for khorramshahr.
# no latitude data for ndende available
# no longitude data for ndende available
# no temperature data for ndende available
# no humidity data for ndende available
# no windspeed data for ndende available
# no cloudiness data for ndende available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ndende.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kysyl-syr.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for salinopolis.
# no latitude data for karauzyak available
# no longitude data for karauzyak available
# no temperature data for karauzyak available
# no humidity data for karauzyak available
# no windspeed data for karauzyak available
# no cloudiness data for karauzyak available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for karauzyak.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for margate.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for toora-khem.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for novovorontsovka.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for manaure.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for pryazha.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for west bay.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for labytnangi.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for jalu.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for palu.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mandan.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for paracuru.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for hobyo.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for san pedro.
# no latitude data for bargal available
# no longitude data for bargal available
# no temperature data for bargal available
# no humidity data for bargal available
# no windspeed data for bargal available
# no cloudiness data for bargal available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bargal.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for adre.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for axim.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for souris.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for ouadda.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for escanaba.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kangaatsiaq.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for aklavik.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for alofi.
# no latitude data for cockburn harbour available
# no longitude data for cockburn harbour available
# no temperature data for cockburn harbour available
# no humidity data for cockburn harbour available
# no windspeed data for cockburn harbour available
# no cloudiness data for cockburn harbour available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for cockburn harbour.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for blajeni.
# no latitude data for saleaula available
# no longitude data for saleaula available
# no temperature data for saleaula available
# no humidity data for saleaula available
# no windspeed data for saleaula available
# no cloudiness data for saleaula available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for saleaula.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kasane.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for harnosand.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for mandera.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for lorengau.
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for bati.
# no latitude data for kankavli available
# no longitude data for kankavli available
# no temperature data for kankavli available
# no humidity data for kankavli available
# no windspeed data for kankavli available
# no cloudiness data for kankavli available
# gathering temperature, coordinates, humidity, cloudiness, and windspeed information for kankavli.

# %%
#store info into a dataframe
weather_dict = {
    #"city": cities_list,
    "lat": test_lat,
    "lon": test_lng,
    "humidity": humidity,
    'temp in celsius': temp,
    "windspeed": windspeed,
    "cloudiness": cloudiness
}
weather_data_df = pd.DataFrame(weather_dict)

weather_data_df.head()
# Out:
#      lat     lon  humidity  temp in celsius  windspeed  cloudiness
# 0 -46.43  -67.52        53            17.33      13.41         100
# 1 -38.31  -60.23        50            16.23       3.88           0
# 2 -25.24  130.99        49             9.00       3.10           0
# 3 -28.77   32.06        69            22.43       4.94           0
# 4 -33.64  115.35        58             9.46       1.49         100

# %%
#convert my celsius temps to fahrenheit

#convert temp to fahrenheit

fahrenheit_temp = []

for temp in weather_data_df['temp in celsius']:
    fahrenheit_temp = (weather_data_df['temp in celsius'] * 9/5) + 32

#weather_data_df.insert(loc=3, column='temp in fahrenheit', value=fahrenheit_temp)

weather_data_df['temp in fahrenheit'] = fahrenheit_temp

weather_data_df.index.name = 'City_ID'

weather_data_df.round(1)

weather_data_df.head()
# Out:
#            lat     lon  humidity  temp in celsius  windspeed  cloudiness  \
# City_ID
# 0       -46.43  -67.52        53            17.33      13.41         100
# 1       -38.31  -60.23        50            16.23       3.88           0
# 2       -25.24  130.99        49             9.00       3.10           0
# 3       -28.77   32.06        69            22.43       4.94           0
# 4       -33.64  115.35        58             9.46       1.49         100
#
#          temp in fahrenheit
# City_ID
# 0                    63.194
# 1                    61.214
# 2                    48.200
# 3                    72.374
# 4                    49.028

# %%
#save dataframe to csv file

weather_data_df.to_csv("WeatherDataFrame")

# %%
#trials to get the scatterplots

x_axis = weather_data_df['lat']

humidity_y_axis = weather_data_df['humidity']

#set limits and label/title the plot
plt.xlim(-100, 100)
plt.title("City Humidity by Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")

#plot the figure incorporating variables
plt.scatter(x_axis, humidity_y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75)

# Save Figure
plt.savefig("./Humidity_by_lat")

plt.show()

# %%
x_axis = weather_data_df['lat']

windspeed_y_axis = weather_data_df['windspeed']

#set limits and label/title the plot
plt.xlim(-100, 100)
plt.title("City Windspeed by Latitude")
plt.xlabel("Latitude")
plt.ylabel("Windspeed (MPH)")

#plot the figure incorporating variables
plt.scatter(x_axis, windspeed_y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75)

# Save Figure
plt.savefig("./Windspeed_by_lat")

plt.show()

# %%
#temperature by latitude

x_axis = weather_data_df['lat']

temp_y_axis = weather_data_df['temp in fahrenheit']

#set limits and label/title the plot
plt.xlim(-100, 100)
plt.title("City Temperature (F) by Latitude")
plt.xlabel("Latitude")
plt.ylabel("Temperature(F)")

#plot the figure incorporating variables
plt.scatter(x_axis, temp_y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75)

# Save Figure
plt.savefig("./Temp_by_lat")

plt.show()

# %%
#cloudiness by latitude

x_axis = weather_data_df['lat']

cloudiness_y_axis = weather_data_df['cloudiness']

#set limits and label/title the plot
plt.xlim(-100, 100)
plt.title("City Cloudiness by Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")

#plot the figure incorporating variables
plt.scatter(x_axis, cloudiness_y_axis, marker="o", facecolors="blue", edgecolors="black",
            alpha=0.75)

# Save Figure
plt.savefig("./Cloudiness_by_lat")

plt.show()
